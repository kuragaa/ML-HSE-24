# %% [markdown]
# <a href="https://colab.research.google.com/github/kuragaa/ML-HSE-24/blob/main/CheatSeet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd

# Создание DataFrame
bikes = pd.read_csv("gdrive/MyDrive/Data_analysis/Практики/BikeData.csv")
bikes.head()
# Out:
#          Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 0  01/12/2017     0         -5.2        37         2.2       0.0       0.0
# 1  01/12/2017     1         -5.5        38         0.8       0.0       0.0
# 2  01/12/2017     2         -6.0        39         1.0       0.0       0.0
# 3  01/12/2017     3         -6.2        40         0.9       0.0       0.0
# 4  01/12/2017     4         -6.0        36         2.3       0.0       0.0
#
#   Seasons     Holiday Functioning Day  Partner 1  Partner 2
# 0  Winter  No Holiday             Yes        207         50
# 1  Winter  No Holiday             Yes        139         80
# 2  Winter  No Holiday             Yes         22        140
# 3  Winter  No Holiday             Yes         43        105
# 4  Winter  No Holiday             Yes         59         38

# %% [markdown]
# # Тема 1 Введение в инструменты + Тема 2 Ввведение в статистику

# %%
bikes.shape
# Out:
# (8760, 12)

# %%
bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             8760 non-null   object
#  1   Hour             8760 non-null   int64
#  2   Temperature      8581 non-null   float64
#  3   Humidity         8760 non-null   int64
#  4   Wind speed       8760 non-null   float64
#  5   Rainfall         8760 non-null   float64
#  6   Snowfall         8760 non-null   float64
#  7   Seasons          8760 non-null   object
#  8   Holiday          8760 non-null   object
#  9   Functioning Day  8760 non-null   object
#  10  Partner 1        8760 non-null   int64
#  11  Partner 2        8760 non-null   int64
# dtypes: float64(4), int64(4), object(4)
# memory usage: 821.4+ KB

# %%
bikes.columns
# Out:
# Index(['Date', 'Hour', 'Temperature', 'Humidity', 'Wind speed', 'Rainfall',
#        'Snowfall', 'Seasons', 'Holiday', 'Functioning Day', 'Partner 1',
#        'Partner 2'],
#       dtype='object')

# %%
bikes.describe()
# Out:
#               Hour  Temperature     Humidity   Wind speed     Rainfall  \
# count  8760.000000  8581.000000  8760.000000  8760.000000  8760.000000
# mean     11.500000    12.878557    58.226256     1.724909     0.148687
# std       6.922582    11.955551    20.362413     1.036300     1.128193
# min       0.000000   -17.800000     0.000000     0.000000     0.000000
# 25%       5.750000     3.400000    42.000000     0.900000     0.000000
# 50%      11.500000    13.700000    57.000000     1.500000     0.000000
# 75%      17.250000    22.500000    74.000000     2.300000     0.000000
# max      23.000000    39.400000    98.000000     7.400000    35.000000
#
#           Snowfall    Partner 1    Partner 2
# count  8760.000000  8760.000000  8760.000000
# mean      0.075068   345.656507   350.925571
# std       0.436746   415.816299   425.687048
# min       0.000000     0.000000     0.000000
# 25%       0.000000    57.000000    56.000000
# 50%       0.000000   186.000000   182.000000
# ...

# %%
bikes['Humidity'].describe()
# Out:
# count    8760.000000
# mean       58.226256
# std        20.362413
# min         0.000000
# 25%        42.000000
# 50%        57.000000
# 75%        74.000000
# max        98.000000
# Name: Humidity, dtype: float64

# %%
bikes['Humidity'].unique()
# Out:
# array([37, 38, 39, 40, 36, 35, 27, 24, 21, 23, 25, 26, 54, 58, 66, 77, 79,
#        81, 83, 84, 87, 86, 82, 68, 57, 49, 41, 48, 51, 53, 52, 55, 56, 69,
#        71, 73, 75, 91, 92, 89, 85, 76, 90, 88, 47, 30, 29, 32, 43, 45, 44,
#        42, 34, 33, 31, 28, 46, 59, 78, 70, 64, 60, 94, 93, 96, 65, 50, 74,
#        63, 61, 72, 62, 22, 67, 80, 95, 15, 20, 17, 18, 16, 19, 14, 97, 98,
#        10, 13, 12, 11,  0])

# %%
bikes.iloc[1]
# Out:
# Date               01/12/2017
# Hour                        1
# Temperature              -5.5
# Humidity                   38
# Wind speed                0.8
# Rainfall                  0.0
# Snowfall                  0.0
# Seasons                Winter
# Holiday            No Holiday
# Functioning Day           Yes
# Partner 1                 139
# Partner 2                  80
# Name: 1, dtype: object

# %%
# Вывод исходных данных
print("Исходные данные:")
print(bikes)
print()
# Out:
# Исходные данные:
#             Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 0     01/12/2017     0         -5.2        37         2.2       0.0       0.0
# 1     01/12/2017     1         -5.5        38         0.8       0.0       0.0
# 2     01/12/2017     2         -6.0        39         1.0       0.0       0.0
# 3     01/12/2017     3         -6.2        40         0.9       0.0       0.0
# 4     01/12/2017     4         -6.0        36         2.3       0.0       0.0
# ...          ...   ...          ...       ...         ...       ...       ...
# 8755  30/11/2018    19          4.2        34         2.6       0.0       0.0
# 8756  30/11/2018    20          3.4        37         2.3       0.0       0.0
# 8757  30/11/2018    21          2.6        39         0.3       0.0       0.0
# 8758  30/11/2018    22          2.1        41         1.0       0.0       0.0
# 8759  30/11/2018    23          1.9        43         1.3       0.0       0.0
#
# ...

# %%
# Фильтрация данных (выбор определенных строк)
filtered_data = bikes[bikes['Temperature'] >= 15]
print("Фильтрация по температуре > 15:")
filtered_data.head()
# Out:
# Фильтрация по температуре > 15:
#             Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 2223  03/03/2018    15         16.0        14         2.2       0.0       0.0
# 2224  03/03/2018    16         15.8        15         2.6       0.0       0.0
# 2225  03/03/2018    17         15.0        22         2.5       0.0       0.0
# 2439  12/03/2018    15         15.3        32         2.9       0.0       0.0
# 2460  13/03/2018    12         15.5        47         3.3       0.0       0.0
#
#      Seasons     Holiday Functioning Day  Partner 1  Partner 2
# 2223  Spring  No Holiday             Yes        965       1236
# 2224  Spring  No Holiday             Yes        532        853
# 2225  Spring  No Holiday             Yes        795        925
# 2439  Spring  No Holiday             Yes         50        271
# 2460  Spring  No Holiday             Yes        302        278

# %%
# Сортировка данных по столбцу Temperature
sorted_data = bikes.sort_values(by='Temperature')
print("Сортировка по температуре:")
sorted_data.head()
# Out:
# Сортировка по температуре:
#             Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 1352  26/01/2018     8        -17.8        40         2.5       0.0       0.5
# 1353  26/01/2018     9        -17.5        37         3.8       0.0       0.5
# 1351  26/01/2018     7        -17.5        38         3.4       0.0       0.5
# 1350  26/01/2018     6        -17.4        40         1.6       0.0       0.5
# 1349  26/01/2018     5        -16.9        38         2.3       0.0       0.5
#
#      Seasons     Holiday Functioning Day  Partner 1  Partner 2
# 1352  Winter  No Holiday             Yes        235        288
# 1353  Winter  No Holiday             Yes         76         26
# 1351  Winter  No Holiday             Yes         93         31
# 1350  Winter  No Holiday             Yes         33         18
# 1349  Winter  No Holiday             Yes         35         21

# %%
# Комбинированный пример: фильтрация и сортировка
combined_data = bikes[bikes['Wind speed'] > 1.4].sort_values(by='Wind speed', ascending=False)
print("Фильтрация по скрости ветра > 1.4 и сортировка по убыванию скорость:")
combined_data.head()
# Out:
# Фильтрация по скрости ветра > 1.4 и сортировка по убыванию скорость:
#             Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 3134  10/04/2018    14         21.2        35         7.4       0.0       0.0
# 3141  10/04/2018    21         17.5        70         7.3       0.5       0.0
# 3138  10/04/2018    18         19.7        52         7.2       0.0       0.0
# 6316  21/08/2018     4         25.3        70         6.9       0.4       0.0
# 933   08/01/2018    21          0.7        77         6.7       0.9       1.0
#
#      Seasons     Holiday Functioning Day  Partner 1  Partner 2
# 3134  Spring  No Holiday             Yes        573        152
# 3141  Spring  No Holiday             Yes         67        115
# 3138  Spring  No Holiday             Yes        953        685
# 6316  Summer  No Holiday             Yes         42         30
# 933   Winter  No Holiday             Yes        108         79

# %%
bikes[(bikes['Holiday'] == 'Holiday')
& (bikes ['Temperature'] >= 15)
& (bikes ['Seasons'] == 'Spring')].shape
# Out:
# (47, 12)

# %%
bikes[(bikes['Holiday'] == 'Holiday') | (bikes['Temperature'] >= 15)].shape
# Out:
# (4310, 12)

# %%
bikes[~((bikes['Holiday'] == 'Holiday') | (bikes['Temperature'] >= 15))].shape #~отрицание
# Out:
# (4450, 12)

# %%
bikes[bikes['Temperature'].isna()].shape #где есть пропущенные значения
# Out:
# (179, 12)

# %%
bikes[bikes['Seasons'].isin(['Winter', 'Summer'])].shape #записи где есть
# Out:
# (4368, 12)

# %%
bikes [bikes ['Temperature']. isin(range (15, 26))].shape
# Out:
# (281, 12)

# %%
bikes[ 'Temperature'].sort_values(ascending=False)
# Out:
# 5848    39.4
# 5847    39.3
# 5849    39.0
# 5846    38.7
# 5825    38.0
#         ...
# 8669     NaN
# 8679     NaN
# 8710     NaN
# 8717     NaN
# 8742     NaN
# Name: Temperature, Length: 8760, dtype: float64

# %%
bikes.sort_values(by=['Temperature', 'Humidity'],ascending=[False, False])
# Out:
#             Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 5848  01/08/2018    16         39.4        39         2.5       0.0       0.0
# 5847  01/08/2018    15         39.3        37         2.3       0.0       0.0
# 5849  01/08/2018    17         39.0        41         2.6       0.0       0.0
# 5846  01/08/2018    14         38.7        38         2.4       0.0       0.0
# 5825  31/07/2018    17         38.0        36         1.3       0.0       0.0
# ...          ...   ...          ...       ...         ...       ...       ...
# 1238  21/01/2018    14          NaN        18         1.2       0.0       0.0
# 1910  18/02/2018    14          NaN        17         1.8       0.0       0.0
# 1886  17/02/2018    14          NaN        15         4.0       0.0       0.0
# 3400  21/04/2018    16          NaN        13         3.3       0.0       0.0
# 4276  28/05/2018     4          NaN         0         0.4       0.0       0.0
#
# ...

# %% [markdown]
# # Тема 3 Переменные

# %%
bikes['Rental Count'] = bikes['Partner 1'] + bikes['Partner 2']

# %%
bikes.head()
# Out:
#          Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 0  01/12/2017     0         -5.2        37         2.2       0.0       0.0
# 1  01/12/2017     1         -5.5        38         0.8       0.0       0.0
# 2  01/12/2017     2         -6.0        39         1.0       0.0       0.0
# 3  01/12/2017     3         -6.2        40         0.9       0.0       0.0
# 4  01/12/2017     4         -6.0        36         2.3       0.0       0.0
#
#   Seasons     Holiday Functioning Day  Partner 1  Partner 2  Rental Count
# 0  Winter  No Holiday             Yes        207         50           257
# 1  Winter  No Holiday             Yes        139         80           219
# 2  Winter  No Holiday             Yes         22        140           162
# 3  Winter  No Holiday             Yes         43        105           148
# 4  Winter  No Holiday             Yes         59         38            97

# %%
bikes.drop('Partner 2', axis=1)
# Out:
#             Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 0     01/12/2017     0         -5.2        37         2.2       0.0       0.0
# 1     01/12/2017     1         -5.5        38         0.8       0.0       0.0
# 2     01/12/2017     2         -6.0        39         1.0       0.0       0.0
# 3     01/12/2017     3         -6.2        40         0.9       0.0       0.0
# 4     01/12/2017     4         -6.0        36         2.3       0.0       0.0
# ...          ...   ...          ...       ...         ...       ...       ...
# 8755  30/11/2018    19          4.2        34         2.6       0.0       0.0
# 8756  30/11/2018    20          3.4        37         2.3       0.0       0.0
# 8757  30/11/2018    21          2.6        39         0.3       0.0       0.0
# 8758  30/11/2018    22          2.1        41         1.0       0.0       0.0
# 8759  30/11/2018    23          1.9        43         1.3       0.0       0.0
#
# ...

# %%
pd.to_datetime(bikes['Date'], dayfirst = True).dt.day
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 8755    30
# 8756    30
# 8757    30
# 8758    30
# 8759    30
# Name: Date, Length: 8760, dtype: int32

# %%
bikes['Date'] = pd.to_datetime(bikes['Date'], dayfirst=True)
bikes[bikes['Date'].dt.month == 3]
# Out:
#            Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 2160 2018-03-01     0          2.0        96         1.3       2.0       0.0
# 2161 2018-03-01     1          2.1        97         0.2       0.0       0.0
# 2162 2018-03-01     2          2.0        97         1.0       0.0       0.0
# 2163 2018-03-01     3          1.6        97         2.3       0.1       0.0
# 2164 2018-03-01     4          1.6        97         1.1       0.0       0.0
# ...         ...   ...          ...       ...         ...       ...       ...
# 2899 2018-03-31    19         15.3        41         2.0       0.0       0.0
# 2900 2018-03-31    20         14.0        45         1.6       0.0       0.0
# 2901 2018-03-31    21         13.3        48         1.6       0.0       0.0
# 2902 2018-03-31    22         12.8        52         1.5       0.0       0.0
# 2903 2018-03-31    23         12.4        63         1.3       0.0       0.0
#
# ...

# %%
bikes[bikes['Date'].dt.day_name() == 'Sunday']
# Out:
#            Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 48   2017-12-03     0          4.0        58         1.4       0.0       0.0
# 49   2017-12-03     1          3.9        69         1.7       0.0       0.0
# 50   2017-12-03     2          NaN        79         1.4       0.0       0.0
# 51   2017-12-03     3          3.4        71         1.6       0.5       0.0
# 52   2017-12-03     4          3.5        73         1.0       0.0       0.0
# ...         ...   ...          ...       ...         ...       ...       ...
# 8635 2018-11-25    19          6.3        73         1.1       0.0       0.4
# 8636 2018-11-25    20          5.5        77         0.7       0.0       0.4
# 8637 2018-11-25    21          4.7        81         1.0       0.0       0.4
# 8638 2018-11-25    22          4.2        82         0.9       0.0       0.4
# 8639 2018-11-25    23          3.8        83         1.1       0.0       0.4
#
# ...

# %%
bikes['Functioning Day'] = bikes ['Functioning Day'] == "Yes"

# %%
bikes.head()
# Out:
#         Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 0 2017-12-01     0         -5.2        37         2.2       0.0       0.0
# 1 2017-12-01     1         -5.5        38         0.8       0.0       0.0
# 2 2017-12-01     2         -6.0        39         1.0       0.0       0.0
# 3 2017-12-01     3         -6.2        40         0.9       0.0       0.0
# 4 2017-12-01     4         -6.0        36         2.3       0.0       0.0
#
#   Seasons     Holiday  Functioning Day  Partner 1  Partner 2  Rental Count
# 0  Winter  No Holiday             True        207         50           257
# 1  Winter  No Holiday             True        139         80           219
# 2  Winter  No Holiday             True         22        140           162
# 3  Winter  No Holiday             True         43        105           148
# 4  Winter  No Holiday             True         59         38            97

# %% [markdown]
# ## условия

# %%
def currency_converter (rub):
    return round(rub / 74.73, 2)
print (currency_converter (1000))
amounts = [1000, 2000, 5000, 124212]
print (list (map(currency_converter, amounts)))
print (list(map(lambda rub: round (rub / 74.73, 2), amounts)))
# Out:
# 13.38
# [13.38, 26.76, 66.91, 1662.14]
# [13.38, 26.76, 66.91, 1662.14]

# %%
bikes['Holiday'].apply(lambda x: 1 if x == 'Holiday' else 0)
bikes.head()
# Out:
#         Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 0 2017-12-01     0         -5.2        37         2.2       0.0       0.0
# 1 2017-12-01     1         -5.5        38         0.8       0.0       0.0
# 2 2017-12-01     2         -6.0        39         1.0       0.0       0.0
# 3 2017-12-01     3         -6.2        40         0.9       0.0       0.0
# 4 2017-12-01     4         -6.0        36         2.3       0.0       0.0
#
#   Seasons     Holiday  Functioning Day  Partner 1  Partner 2  Rental Count
# 0  Winter  No Holiday             True        207         50           257
# 1  Winter  No Holiday             True        139         80           219
# 2  Winter  No Holiday             True         22        140           162
# 3  Winter  No Holiday             True         43        105           148
# 4  Winter  No Holiday             True         59         38            97

# %%
bikes[bikes['Holiday'] == 'Holiday']
# Out:
#            Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 504  2017-12-22     0         -1.7        79         0.5       0.0       0.8
# 505  2017-12-22     1         -1.6        79         0.6       0.0       0.8
# 506  2017-12-22     2         -1.1        79         0.7       0.0       0.8
# 507  2017-12-22     3         -0.6        76         0.5       0.0       0.7
# 508  2017-12-22     4         -0.3        76         0.9       0.0       0.7
# ...         ...   ...          ...       ...         ...       ...       ...
# 7507 2018-10-09    19         17.3        47         2.2       0.0       0.0
# 7508 2018-10-09    20         17.0        49         1.4       0.0       0.0
# 7509 2018-10-09    21         16.8        52         1.6       0.0       0.0
# 7510 2018-10-09    22         16.7        55         1.9       0.0       0.0
# 7511 2018-10-09    23         16.6        53         1.1       0.0       0.0
#
# ...

# %%
bikes['Holiday_2'] = bikes['Holiday'].apply(lambda x: 1 if x == 'Holiday' else 0)

# %%
bikes.head()
# Out:
#         Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 0 2017-12-01     0         -5.2        37         2.2       0.0       0.0
# 1 2017-12-01     1         -5.5        38         0.8       0.0       0.0
# 2 2017-12-01     2         -6.0        39         1.0       0.0       0.0
# 3 2017-12-01     3         -6.2        40         0.9       0.0       0.0
# 4 2017-12-01     4         -6.0        36         2.3       0.0       0.0
#
#   Seasons     Holiday  Functioning Day  Partner 1  Partner 2  Rental Count  \
# 0  Winter  No Holiday             True        207         50           257
# 1  Winter  No Holiday             True        139         80           219
# 2  Winter  No Holiday             True         22        140           162
# 3  Winter  No Holiday             True         43        105           148
# 4  Winter  No Holiday             True         59         38            97
#
#    Holiday_2
# 0          0
# 1          0
# 2          0
# ...

# %%
bikes['Normal Humidity'] = bikes[ 'Humidity'].apply(lambda x: 1 if x in range(40,61) else 0)

# %% [markdown]
# ## Категориальные переменные - 02.03

# %%
def get_temp_cat (temp):
    if temp < 0:
        return 'Freezing'
    elif temp < 15:
        return 'Chilly'
    elif temp < 26:
        return 'Nice'
    elif temp >= 26:
        return 'Hot'
    else:
        return temp

# %%
bikes['Temperature Category'] = bikes['Temperature'].apply(get_temp_cat)
bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  8760 non-null   datetime64[ns]
#  1   Hour                  8760 non-null   int64
#  2   Temperature           8581 non-null   float64
#  3   Humidity              8760 non-null   int64
#  4   Wind speed            8760 non-null   float64
#  5   Rainfall              8760 non-null   float64
#  6   Snowfall              8760 non-null   float64
#  7   Seasons               8760 non-null   object
#  8   Holiday               8760 non-null   object
#  9   Functioning Day       8760 non-null   bool
#  10  Partner 1             8760 non-null   int64
#  11  Partner 2             8760 non-null   int64
#  12  Rental Count          8760 non-null   int64
#  13  Holiday_2             8760 non-null   int64
#  14  Normal Humidity       8760 non-null   int64
# ...

# %%
bikes['Temperature Category'] = pd.Categorical(bikes['Temperature Category'])
bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  8760 non-null   datetime64[ns]
#  1   Hour                  8760 non-null   int64
#  2   Temperature           8581 non-null   float64
#  3   Humidity              8760 non-null   int64
#  4   Wind speed            8760 non-null   float64
#  5   Rainfall              8760 non-null   float64
#  6   Snowfall              8760 non-null   float64
#  7   Seasons               8760 non-null   object
#  8   Holiday               8760 non-null   object
#  9   Functioning Day       8760 non-null   bool
#  10  Partner 1             8760 non-null   int64
#  11  Partner 2             8760 non-null   int64
#  12  Rental Count          8760 non-null   int64
#  13  Holiday_2             8760 non-null   int64
#  14  Normal Humidity       8760 non-null   int64
# ...

# %%
import numpy as np

# %%
bikes['Good Weather'] = np.where((bikes[ 'Temperature Category'] == 'Nice')
                                  & (bikes ['Normal Humidity'] == 1)
                                  & (bikes ['Wind speed'] <= 5.4)
                                  & (bikes ['Snowfall'] == 0)
                                  & (bikes ['Rainfall'] == 0), 1, 0)

bikes.head()
# Out:
#         Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 0 2017-12-01     0         -5.2        37         2.2       0.0       0.0
# 1 2017-12-01     1         -5.5        38         0.8       0.0       0.0
# 2 2017-12-01     2         -6.0        39         1.0       0.0       0.0
# 3 2017-12-01     3         -6.2        40         0.9       0.0       0.0
# 4 2017-12-01     4         -6.0        36         2.3       0.0       0.0
#
#   Seasons     Holiday  Functioning Day  Partner 1  Partner 2  Rental Count  \
# 0  Winter  No Holiday             True        207         50           257
# 1  Winter  No Holiday             True        139         80           219
# 2  Winter  No Holiday             True         22        140           162
# 3  Winter  No Holiday             True         43        105           148
# 4  Winter  No Holiday             True         59         38            97
#
#    Holiday_2  Normal Humidity Temperature Category  Good Weather
# ...

# %%
bikes.to_csv('BikesDataVars.csv', index=False)
bikes.to_excel('BikesDataVars.xlsx', index=False)
df = pd.read_csv('BikesDataVars.csv')#меньше инф
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  8760 non-null   object
#  1   Hour                  8760 non-null   int64
#  2   Temperature           8581 non-null   float64
#  3   Humidity              8760 non-null   int64
#  4   Wind speed            8760 non-null   float64
#  5   Rainfall              8760 non-null   float64
#  6   Snowfall              8760 non-null   float64
#  7   Seasons               8760 non-null   object
#  8   Holiday               8760 non-null   object
#  9   Functioning Day       8760 non-null   bool
#  10  Partner 1             8760 non-null   int64
#  11  Partner 2             8760 non-null   int64
#  12  Rental Count          8760 non-null   int64
#  13  Holiday_2             8760 non-null   int64
#  14  Normal Humidity       8760 non-null   int64
# ...

# %%
df = pd.read_csv('BikesDataVars.csv')#больше, но не все
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  8760 non-null   object
#  1   Hour                  8760 non-null   int64
#  2   Temperature           8581 non-null   float64
#  3   Humidity              8760 non-null   int64
#  4   Wind speed            8760 non-null   float64
#  5   Rainfall              8760 non-null   float64
#  6   Snowfall              8760 non-null   float64
#  7   Seasons               8760 non-null   object
#  8   Holiday               8760 non-null   object
#  9   Functioning Day       8760 non-null   bool
#  10  Partner 1             8760 non-null   int64
#  11  Partner 2             8760 non-null   int64
#  12  Rental Count          8760 non-null   int64
#  13  Holiday_2             8760 non-null   int64
#  14  Normal Humidity       8760 non-null   int64
# ...

# %%
bikes.to_pickle('BikesDataVars.pkl')
df = pd.read_pickle('BikesDataVars.pkl')#все
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  8760 non-null   datetime64[ns]
#  1   Hour                  8760 non-null   int64
#  2   Temperature           8581 non-null   float64
#  3   Humidity              8760 non-null   int64
#  4   Wind speed            8760 non-null   float64
#  5   Rainfall              8760 non-null   float64
#  6   Snowfall              8760 non-null   float64
#  7   Seasons               8760 non-null   object
#  8   Holiday               8760 non-null   object
#  9   Functioning Day       8760 non-null   bool
#  10  Partner 1             8760 non-null   int64
#  11  Partner 2             8760 non-null   int64
#  12  Rental Count          8760 non-null   int64
#  13  Holiday_2             8760 non-null   int64
#  14  Normal Humidity       8760 non-null   int64
# ...

# %% [markdown]
# value_counts()

# %%
bikes['Holiday'].value_counts()
# Out:
# Holiday
# No Holiday    8328
# Holiday        432
# Name: count, dtype: int64

# %%
bikes.value_counts(subset='Holiday')#какие столбцы используются
# Out:
# Holiday
# No Holiday    8328
# Holiday        432
# Name: count, dtype: int64

# %% [markdown]
# Параметр subset
# Параметр ascending
# =false - сортирует в порядке убывания =true - сортирует в порядке возрастания

# %%
bikes.value_counts(subset=['Holiday', 'Seasons' ])
# Out:
# Holiday     Seasons
# No Holiday  Summer     2160
#             Spring     2136
#             Autumn     2064
#             Winter     1968
# Holiday     Winter      192
#             Autumn      120
#             Spring       72
#             Summer       48
# Name: count, dtype: int64

# %%
bikes.value_counts(subset=None, ascending=False, dropna=True) # df.value_counts (›
# Out:
# Date        Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  Seasons  Holiday     Functioning Day  Partner 1  Partner 2  Rental Count  Holiday_2  Normal Humidity  Temperature Category  Good Weather
# 2017-12-01  0     -5.2         37        2.2         0.0       0.0       Winter   No Holiday  True             207        50         257           0          0                Freezing              0               1
# 2018-07-31  22     31.6        66        3.0         0.0       0.0       Summer   No Holiday  True             913        119        1032          0          0                Hot                   0               1
# 2018-08-01  12     36.8        39        1.3         0.0       0.0       Summer   No Holiday  True             454        426        880           0          0                Hot                   0               1
# ...

# %% [markdown]
# Параметр ascending
# =false - сортирует в порядке убывания =true - сортирует в порядке возрастания
# df[ 'Holiday' ] •value_counts (asgending-False)
# No Holiday
# 8328
# Holiday
# 432
# Name: Holiday, dtype: int64
# df[ 'Holiday' ].value_counts (ascending=True)
# Holiday
# 432
# No Holiday
# 8328
# Name: Holiday, dtype: int64
# Параметр dropna
# =false - показывает количество пропущенных значений (NaN) =true - не показывает количество пропущенных значений (NaN)

# %% [markdown]
# # Тема 4 Генеральная совокупность и выборка

# %%
bikes['Temperature Category'].value_counts()
# Out:
# Temperature Category
# Chilly      3112
# Nice        2778
# Freezing    1412
# Hot         1279
# Name: count, dtype: int64

# %%
bikes['Temperature Category'].value_counts(dropna=False)
# Out:
# Temperature Category
# Chilly      3112
# Nice        2778
# Freezing    1412
# Hot         1279
# NaN          179
# Name: count, dtype: int64

# %%
bikes.groupby('Date')['Rental Count'].count()
# Out:
# Date
# 2017-12-01    24
# 2017-12-02    24
# 2017-12-03    24
# 2017-12-04    24
# 2017-12-05    24
#               ..
# 2018-11-26    24
# 2018-11-27    24
# 2018-11-28    24
# 2018-11-29    24
# 2018-11-30    24
# Name: Rental Count, Length: 365, dtype: int64

# %%
bikes['Seasons'].value_counts(dropna = False)
# Out:
# Seasons
# Spring    2208
# Summer    2208
# Autumn    2184
# Winter    2160
# Name: count, dtype: int64

# %%
bikes.groupby('Seasons', dropna = False).size()
# Out:
# Seasons
# Autumn    2184
# Spring    2208
# Summer    2208
# Winter    2160
# dtype: int64

# %%
bikes.groupby('Seasons')['Good Weather'].value_counts()
# Out:
# Seasons  Good Weather
# Autumn   0               1861
#          1                323
# Spring   0               1949
#          1                259
# Summer   0               1978
#          1                230
# Winter   0               2160
# Name: count, dtype: int64

# %%
bikes.groupby(['Seasons', 'Temperature Category'])['Rental Count'].sum()
# Out:
# Seasons  Temperature Category
# Autumn   Chilly                   775694
#          Freezing                  12035
#          Hot                      134156
#          Nice                     811498
# Spring   Chilly                   587211
#          Freezing                   6331
#          Hot                       52993
#          Nice                     928572
# Summer   Chilly                        0
#          Freezing                      0
#          Hot                     1315525
#          Nice                     892664
# Winter   Chilly                   215221
#          Freezing                 258570
#          Hot                           0
#          Nice                          0
# Name: Rental Count, dtype: int64

# %% [markdown]
# ## Гистограммы

# %%
bikes['Temperature'].hist()# bikes [ 'Temperature'].hist(bins=20) группировка по 20
# Out:
# <Axes: >

# %%
bikes[ 'Temperature'].hist(bins=20) # группировка по 20
# Out:
# <Axes: >

# %%
bikes['Temperature Category'].value_counts()
# Out:
# Temperature Category
# Chilly      3112
# Nice        2778
# Freezing    1412
# Hot         1279
# Name: count, dtype: int64

# %%
bikes['Temperature Category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Temperature Category'>

# %%
bikes.groupby('Seasons')['Temperature Category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Seasons,Temperature Category'>

# %%
bikes.groupby('Seasons')['Temperature Category'].value_counts().unstack()
# Out:
# Temperature Category  Chilly  Freezing   Hot  Nice
# Seasons
# Autumn                  1138        20    86   894
# Spring                  1224        22    27   881
# Summer                     0         0  1166  1003
# Winter                   750      1370     0     0

# %%
bikes.groupby('Seasons')['Temperature Category'].value_counts().unstack().plot(kind='bar')
# Out:
# <Axes: xlabel='Seasons'>

# %%
bikes.groupby('Seasons')['Temperature Category'].value_counts().unstack().plot(kind='bar', stacked = True)
# Out:
# <Axes: xlabel='Seasons'>

# %% [markdown]
# # Тема 5 Описательная стастистика: меры центральной тенденции и разброса 09.03

# %%
bikes['Rental Count'] = bikes['Partner 1'] + bikes['Partner 2']

# %%
bikes.head()
# Out:
#         Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 0 2017-12-01     0         -5.2        37         2.2       0.0       0.0
# 1 2017-12-01     1         -5.5        38         0.8       0.0       0.0
# 2 2017-12-01     2         -6.0        39         1.0       0.0       0.0
# 3 2017-12-01     3         -6.2        40         0.9       0.0       0.0
# 4 2017-12-01     4         -6.0        36         2.3       0.0       0.0
#
#   Seasons     Holiday  Functioning Day  Partner 1  Partner 2  Rental Count  \
# 0  Winter  No Holiday             True        207         50           257
# 1  Winter  No Holiday             True        139         80           219
# 2  Winter  No Holiday             True         22        140           162
# 3  Winter  No Holiday             True         43        105           148
# 4  Winter  No Holiday             True         59         38            97
#
#    Holiday_2  Normal Humidity Temperature Category  Good Weather
# ...

# %%
bikes ['Humidity'].sum() / len(bikes['Humidity'])
# Out:
# 58.226255707762554

# %%
bikes ['Humidity' ].mean()
# Out:
# 58.226255707762554

# %%
hum_sorted = bikes['Humidity'].sort_values().reset_index(drop=True)
#hum_sorted[len(hum_sorted)] = 28
#print(hum_sorted)
print(len(hum_sorted))
#если значение нечетное
ind_1, ind_2 = int(len(hum_sorted) / 2), int(len (hum_sorted) / 2 + 1)
print (ind_1, ind_2)
print((hum_sorted[ind_1] + hum_sorted[ind_2]) / 2)
#если четное
print(hum_sorted[len(hum_sorted)/2])
# Out:
# 8760
# 4380 4381
# 57.0
# 57

# %%
bikes ['Humidity'].median()
# Out:
# 57.0

# %%
bikes ['Humidity'].mode()
# Out:
# 0    53
# 1    97
# Name: Humidity, dtype: int64

# %%
bikes['Humidity'].hist(bins=100)
# Out:
# <Axes: >

# %%
bikes.describe()
# Out:
#                                 Date         Hour  Temperature     Humidity  \
# count                           8760  8760.000000  8581.000000  8760.000000
# mean   2018-05-31 23:59:59.999999744    11.500000    12.878557    58.226256
# min              2017-12-01 00:00:00     0.000000   -17.800000     0.000000
# 25%              2018-03-02 00:00:00     5.750000     3.400000    42.000000
# 50%              2018-06-01 00:00:00    11.500000    13.700000    57.000000
# 75%              2018-08-31 00:00:00    17.250000    22.500000    74.000000
# max              2018-11-30 00:00:00    23.000000    39.400000    98.000000
# std                              NaN     6.922582    11.955551    20.362413
#
#         Wind speed     Rainfall     Snowfall    Partner 1    Partner 2  \
# count  8760.000000  8760.000000  8760.000000  8760.000000  8760.000000
# mean      1.724909     0.148687     0.075068   345.656507   350.925571
# ...

# %%
bikes.groupby('Hour')['Rental Count'].mean()
# Out:
# Hour
# 0      558.178082
# 1      415.720548
# 2      319.767123
# 3      201.010959
# 4      122.838356
# 5      135.863014
# 6      283.654795
# 7      612.646575
# 8      979.838356
# 9      642.136986
# 10     519.123288
# 11     585.336986
# 12     710.534247
# 13     700.706849
# 14     747.147945
# 15     796.084932
# 16     938.032877
# 17    1128.873973
# 18    1518.983562
# 19    1168.328767
# 20    1069.698630
# 21     997.942466
# 22     893.621918
# 23     671.898630
# Name: Rental Count, dtype: float64

# %%
bikes.groupby(['Hour', 'Good Weather'])['Rental Count'].mean()
# Out:
# Hour  Good Weather
# 0     0                514.797619
#       1               1060.793103
# 1     0                399.179941
#       1                631.384615
# 2     0                304.476608
#       1                547.130435
# 3     0                193.178161
#       1                361.352941
# 4     0                119.467236
#       1                207.357143
# 5     0                131.218487
#       1                343.125000
# 6     0                279.243017
#       1                509.285714
# 7     0                604.888571
#       1                793.666667
# 8     0                957.336336
#       1               1214.000000
# 9     0                598.072327
#       1                940.276596
# 10    0                478.721154
#       1                756.962264
# 11    0                514.022801
#       1                962.810345
# 12    0                664.558065
#       1                969.672727
# 13    0                674.304075
# ...

# %%
bikes.groupby('Seasons')['Temperature Category'].agg(lambda x: x.value_counts().index[0])
# Out:
# Seasons
# Autumn      Chilly
# Spring      Chilly
# Summer         Hot
# Winter    Freezing
# Name: Temperature Category, dtype: object

# %%
bikes.groupby( 'Seasons') ['Temperature'].agg(['mean', 'median'])
# Out:
#               mean  median
# Seasons
# Autumn   14.138821    13.8
# Spring   13.038533    13.3
# Summer   26.574827    26.6
# Winter   -2.567783    -2.2

# %%
bikes.pivot_table(index='Hour',
                values=[ 'Temperature', 'Rental Count'],
                  aggfunc=['mean', 'median'])
# Out:
#              mean                   median
#      Rental Count Temperature Rental Count Temperature
# Hour
# 0      558.178082   11.253652          433       11.80
# 1      415.720548   10.972145          329       11.50
# 2      319.767123   10.542535          239       10.90
# 3      201.010959   10.355462          165       10.70
# 4      122.838356   10.069859           94       10.40
# 5      135.863014    9.849580          107       10.00
# 6      283.654795    9.763944          193       10.00
# 7      612.646575    9.454062          410        9.60
# 8      979.838356    9.988515          762       10.40
# 9      642.136986   11.459669          519       12.10
# 10     519.123288   12.766947          414       14.00
# 11     585.336986   14.285434          485       16.40
# 12     710.534247   15.417175          572       17.40
# 13     700.706849   16.184765          586       18.30
# 14     747.147945   16.862360          567       19.10
# ...

# %%
bikes_hour = pd.DataFrame(bikes.groupby( 'Hour')[ 'Rental Count'].sum())
bikes_hour.plot(kind='bar')
# Out:
# <Axes: xlabel='Hour'>

# %% [markdown]
# Методы разброса

# %%
bikes_hour ['Rental Count'].max() - bikes_hour ['Rental Count'].min() # размах
# Out:
# 509593

# %%
bikes_hour.describe()['Rental Count' ]['25%']
# Out:
# 180044.5

# %%
np.percentile(bikes_hour[ 'Rental Count'], 25)
# Out:
# 180044.5

# %%
np.percentile(bikes_hour['Rental Count'], 75)-np. percentile(bikes_hour[ 'Rental Count'], 25) # интерквартильный размах
# Out:
# 166152.25

# %%
bikes_mean = bikes_hour['Rental Count'].mean()
deviations = bikes_hour['Rental Count'] - bikes_mean #отклонение

sq_deviations = deviations ** 2 #квадрат отклонения
variance_samp = sq_deviations.sum()/ len(bikes_hour) - 1 # Для выборки колличество вычислений -1
std_samp = np.sqrt(variance_samp)
print(variance_samp, std_samp)
# Out:
# 15876133225.41493 126000.52867117237

# %%
variance_pop = sq_deviations.sum()/(len(bikes_hour))#генеральная совокупность
std_pop = np.sqrt(variance_pop)
print (variance_pop, std_pop)
# Out:
# 15876133226.41493 126000.52867514061

# %%
print(bikes_hour['Rental Count'].var())#дисперсия
print(bikes_hour['Rental Count'].std())#среднеквадратичное отелонение
# Out:
# 16566399888.43297
# 128710.52749652209

# %%
print(bikes_hour['Rental Count' ].var(ddof=0))#генеральная совокупность
print(bikes_hour['Rental Count'].std(ddof=0))
# Out:
# 15876133226.41493
# 126000.52867514061

# %%
def range_values(x):
    return x.max() - x.min()
bikes. pivot_table(index='Hour',
values=[ 'Temperature', 'Rental Count'], aggfunc=['var', 'std', range_values])
# Out:
#                var                      std             range_values  \
#       Rental Count Temperature Rental Count Temperature Rental Count
# Hour
# 0     2.070397e+05  130.823339   455.016192   11.437803         2059
# 1     1.142838e+05  129.769278   338.058896   11.391632         1485
# 2     7.225204e+04  130.217762   268.797389   11.411300         1950
# 3     2.643931e+04  127.842870   162.601701   11.306762          781
# 4     1.131581e+04  127.332677   106.375778   11.284178          608
# 5     1.281241e+04  127.921327   113.191916   11.310231          561
# 6     7.487706e+04  128.232369   273.636723   11.323973         1577
# 7     3.393248e+05  131.970580   582.515881   11.487845         2880
# 8     7.586514e+05  142.368491   871.005983   11.931827         4438
# 9     2.500188e+05  148.816319   500.018849   12.199029         2318
# 10    1.724559e+05  147.593567   415.278139   12.148809         1740
# ...

# %% [markdown]
# # Тема 6 Z-оценка и выбросы

# %%
bikes.head()
# Out:
#         Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 0 2017-12-01     0         -5.2        37         2.2       0.0       0.0
# 1 2017-12-01     1         -5.5        38         0.8       0.0       0.0
# 2 2017-12-01     2         -6.0        39         1.0       0.0       0.0
# 3 2017-12-01     3         -6.2        40         0.9       0.0       0.0
# 4 2017-12-01     4         -6.0        36         2.3       0.0       0.0
#
#   Seasons     Holiday  Functioning Day  Partner 1  Partner 2  Rental Count  \
# 0  Winter  No Holiday             True        207         50           257
# 1  Winter  No Holiday             True        139         80           219
# 2  Winter  No Holiday             True         22        140           162
# 3  Winter  No Holiday             True         43        105           148
# 4  Winter  No Holiday             True         59         38            97
#
#    Holiday_2  Normal Humidity Temperature Category  Good Weather
# ...

# %%
bikes.describe()
# Out:
#                                 Date         Hour  Temperature     Humidity  \
# count                           8760  8760.000000  8581.000000  8760.000000
# mean   2018-05-31 23:59:59.999999744    11.500000    12.878557    58.226256
# min              2017-12-01 00:00:00     0.000000   -17.800000     0.000000
# 25%              2018-03-02 00:00:00     5.750000     3.400000    42.000000
# 50%              2018-06-01 00:00:00    11.500000    13.700000    57.000000
# 75%              2018-08-31 00:00:00    17.250000    22.500000    74.000000
# max              2018-11-30 00:00:00    23.000000    39.400000    98.000000
# std                              NaN     6.922582    11.955551    20.362413
#
#         Wind speed     Rainfall     Snowfall    Partner 1    Partner 2  \
# count  8760.000000  8760.000000  8760.000000  8760.000000  8760.000000
# mean      1.724909     0.148687     0.075068   345.656507   350.925571
# ...

# %%
q3 = np. percentile(bikes['Rental Count'], 75)
q1 = np. percentile(bikes['Rental Count'], 25)
print(q3, q1)
# Out:
# 1009.0 157.0

# %%
iqr = q3 - q1
print(iqr)

iqr_threshold_bottom = q1 - 1.5 * iqr
iqr_threshold_top = q3 + 1.5 * iqr
print(iqr_threshold_bottom, iqr_threshold_top)
# Out:
# 852.0
# -1121.0 2287.0

# %%
bikes[bikes['Rental Count'] > iqr_threshold_top].shape
# Out:
# (413, 17)

# %%
bikes[bikes['Rental Count'] > iqr_threshold_top].groupby(['Hour']).size()
# Out:
# Hour
# 7      4
# 8     38
# 9      1
# 13     7
# 14     8
# 15    10
# 16    23
# 17    51
# 18    95
# 19    64
# 20    48
# 21    39
# 22    21
# 23     4
# dtype: int64

# %%
bikes['Hour'].value_counts()
# Out:
# Hour
# 0     365
# 1     365
# 22    365
# 21    365
# 20    365
# 19    365
# 18    365
# 17    365
# 16    365
# 15    365
# 14    365
# 13    365
# 12    365
# 11    365
# 10    365
# 9     365
# 8     365
# 7     365
# 6     365
# 5     365
# 4     365
# 3     365
# 2     365
# 23    365
# Name: count, dtype: int64

# %%
bikes[bikes['Rental Count'] > iqr_threshold_top]['Seasons'].value_counts()
# Out:
# Seasons
# Summer    196
# Autumn    116
# Spring    101
# Name: count, dtype: int64

# %%
bikes['Seasons'].value_counts()
# Out:
# Seasons
# Spring    2208
# Summer    2208
# Autumn    2184
# Winter    2160
# Name: count, dtype: int64

# %%
mean = bikes['Rental Count'].mean ()
std = bikes ['Rental Count'].std()
std_threshold_bottom = mean - 2.5 * std
std_threshold_top = mean + 2.5 * std
print(std_threshold_bottom, std_threshold_top)
# Out:
# -1177.949455164326 2571.113610415468

# %%
bikes[bikes['Rental Count'] > std_threshold_top].shape
# Out:
# (278, 17)

# %%
bikes[bikes['Rental Count'] > std_threshold_top].shape
# Out:
# (278, 17)

# %%
iqr_no_outliers = bikes[bikes['Rental Count'] <= iqr_threshold_top]
std_no_outliers = bikes[bikes['Rental Count'] <= std_threshold_top]

# %%
print(bikes['Rental Count'].mean())
print(iqr_no_outliers['Rental Count'].mean())
print(std_no_outliers['Rental Count'].mean())
# Out:
# 696.5820776255708
# 584.146280100635
# 613.2393303466164

# %%
print(bikes['Rental Count'].median())
print(iqr_no_outliers['Rental Count'].median())
print(std_no_outliers['Rental Count'].median())
# Out:
# 425.5
# 392.0
# 402.0

# %% [markdown]
# Работа с пропущеннными значениями

# %%
bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  8760 non-null   datetime64[ns]
#  1   Hour                  8760 non-null   int64
#  2   Temperature           8581 non-null   float64
#  3   Humidity              8760 non-null   int64
#  4   Wind speed            8760 non-null   float64
#  5   Rainfall              8760 non-null   float64
#  6   Snowfall              8760 non-null   float64
#  7   Seasons               8760 non-null   object
#  8   Holiday               8760 non-null   object
#  9   Functioning Day       8760 non-null   bool
#  10  Partner 1             8760 non-null   int64
#  11  Partner 2             8760 non-null   int64
#  12  Rental Count          8760 non-null   int64
#  13  Holiday_2             8760 non-null   int64
#  14  Normal Humidity       8760 non-null   int64
# ...

# %%
bikes.describe()
# Out:
#                                 Date         Hour  Temperature     Humidity  \
# count                           8760  8760.000000  8581.000000  8760.000000
# mean   2018-05-31 23:59:59.999999744    11.500000    12.878557    58.226256
# min              2017-12-01 00:00:00     0.000000   -17.800000     0.000000
# 25%              2018-03-02 00:00:00     5.750000     3.400000    42.000000
# 50%              2018-06-01 00:00:00    11.500000    13.700000    57.000000
# 75%              2018-08-31 00:00:00    17.250000    22.500000    74.000000
# max              2018-11-30 00:00:00    23.000000    39.400000    98.000000
# std                              NaN     6.922582    11.955551    20.362413
#
#         Wind speed     Rainfall     Snowfall    Partner 1    Partner 2  \
# count  8760.000000  8760.000000  8760.000000  8760.000000  8760.000000
# mean      1.724909     0.148687     0.075068   345.656507   350.925571
# ...

# %%
bikes.isna().sum()
# Out:
# Date                      0
# Hour                      0
# Temperature             179
# Humidity                  0
# Wind speed                0
# Rainfall                  0
# Snowfall                  0
# Seasons                   0
# Holiday                   0
# Functioning Day           0
# Partner 1                 0
# Partner 2                 0
# Rental Count              0
# Holiday_2                 0
# Normal Humidity           0
# Temperature Category    179
# Good Weather              0
# dtype: int64

# %%
type(bikes[bikes ['Temperature'].isna()]['Temperature'][39])
# Out:
# numpy.float64

# %%
bikes.dropna(subset=[ 'Temperature']).shape
# Out:
# (8581, 17)

# %%
bikes ['Temperature _Median'] = bikes ['Temperature']. fillna(bikes[ 'Temperature'].median())
bikes [bikes ['Temperature'].isna()].head()
# Out:
#           Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 39  2017-12-02    15          NaN        41         2.3       0.0       0.0
# 50  2017-12-03     2          NaN        79         1.4       0.0       0.0
# 64  2017-12-03    16          NaN        77         1.6       0.0       0.0
# 105 2017-12-05     9          NaN        31         1.3       0.0       0.0
# 151 2017-12-07     7          NaN        93         0.5       0.0       0.9
#
#     Seasons     Holiday  Functioning Day  Partner 1  Partner 2  Rental Count  \
# 39   Winter  No Holiday             True        490        198           688
# 50   Winter  No Holiday             True        208         54           262
# 64   Winter  No Holiday             True         49        528           577
# 105  Winter  No Holiday             True         78        235           313
# 151  Winter  No Holiday             True        140        129           269
#
# ...

# %%
bikes.head()
# Out:
#         Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 0 2017-12-01     0         -5.2        37         2.2       0.0       0.0
# 1 2017-12-01     1         -5.5        38         0.8       0.0       0.0
# 2 2017-12-01     2         -6.0        39         1.0       0.0       0.0
# 3 2017-12-01     3         -6.2        40         0.9       0.0       0.0
# 4 2017-12-01     4         -6.0        36         2.3       0.0       0.0
#
#   Seasons     Holiday  Functioning Day  Partner 1  Partner 2  Rental Count  \
# 0  Winter  No Holiday             True        207         50           257
# 1  Winter  No Holiday             True        139         80           219
# 2  Winter  No Holiday             True         22        140           162
# 3  Winter  No Holiday             True         43        105           148
# 4  Winter  No Holiday             True         59         38            97
#
#    Holiday_2  Normal Humidity Temperature Category  Good Weather  \
# ...

# %%
bikes.iloc[38:42]
# Out:
#          Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 38 2017-12-02    14          7.3        35         1.3       0.0       0.0
# 39 2017-12-02    15          NaN        41         2.3       0.0       0.0
# 40 2017-12-02    16          6.4        48         2.6       0.0       0.0
# 41 2017-12-02    17          6.0        51         2.5       0.0       0.0
#
#    Seasons     Holiday  Functioning Day  Partner 1  Partner 2  Rental Count  \
# 38  Winter  No Holiday             True        495        559          1054
# 39  Winter  No Holiday             True        490        198           688
# 40  Winter  No Holiday             True        476        116           592
# 41  Winter  No Holiday             True         95         46           141
#
#     Holiday_2  Normal Humidity Temperature Category  Good Weather  \
# 38          0                0               Chilly             0
# 39          0                1                  NaN             0
# ...

# %%
temps_random = np. random. choice(bikes ['Temperature'].dropna(), 8760)
bikes ['Temperature_Random'] = bikes[ 'Temperature']. fillna(pd.Series(temps_random))
bikes [bikes ['Temperature']. isna ()].head()
# Out:
#           Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 39  2017-12-02    15          NaN        41         2.3       0.0       0.0
# 50  2017-12-03     2          NaN        79         1.4       0.0       0.0
# 64  2017-12-03    16          NaN        77         1.6       0.0       0.0
# 105 2017-12-05     9          NaN        31         1.3       0.0       0.0
# 151 2017-12-07     7          NaN        93         0.5       0.0       0.9
#
#     Seasons     Holiday  Functioning Day  Partner 1  Partner 2  Rental Count  \
# 39   Winter  No Holiday             True        490        198           688
# 50   Winter  No Holiday             True        208         54           262
# 64   Winter  No Holiday             True         49        528           577
# 105  Winter  No Holiday             True         78        235           313
# 151  Winter  No Holiday             True        140        129           269
#
# ...

# %%
bikes.iloc[38:42]
# Out:
#          Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 38 2017-12-02    14          7.3        35         1.3       0.0       0.0
# 39 2017-12-02    15          NaN        41         2.3       0.0       0.0
# 40 2017-12-02    16          6.4        48         2.6       0.0       0.0
# 41 2017-12-02    17          6.0        51         2.5       0.0       0.0
#
#    Seasons     Holiday  Functioning Day  Partner 1  Partner 2  Rental Count  \
# 38  Winter  No Holiday             True        495        559          1054
# 39  Winter  No Holiday             True        490        198           688
# 40  Winter  No Holiday             True        476        116           592
# 41  Winter  No Holiday             True         95         46           141
#
#     Holiday_2  Normal Humidity Temperature Category  Good Weather  \
# 38          0                0               Chilly             0
# 39          0                1                  NaN             0
# ...

# %%
bikes.groupby([bikes[ 'Date'].dt.week['Hour'])['Temperature'].median()
# Out:
#   File "<ipython-input-113-ac02cd128d33>", line 1
#     bikes.groupby([bikes[ 'Date'].dt.week['Hour'])['Temperature'].median()
#                                                  ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
temp_median = bikes.groupby([bikes[ 'Date'].dt.week, 'Hour'])['Temperature'].transform('median')
bikes ['Temperature Median Group'] = bikes ['Temperature']. fillna(temp_median)
bikes [bikes ['Temperature']. isna ()].head()

# %%
bikes.iloc[38:42]

# %%
bikes['Temperature'] = bikes['Temperature'].fillna(temp_median)
del bikes['Temperature _Median']
del bikes['Temperature_Random']
del bikes['Temperature Median Group']

# %%
bikes['Temperature Category'] = pd.Categorical(bikes['Temperature'].apply(get_temp_cat))
bikes.head()

# %%
bikes.to_pickle('gdrive/MyDrive/Data_analysis/Практики/BikesDataImputed.pk1')

# %% [markdown]
# # Тема 7 Корреляция

# %%
temp_mean = bikes.groupby(bikes['Date'].dt.week)['Temperature'].mean()
bikes_sum = bikes.groupby(bikes['Date'].dt.week)['Rental Count'].sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-115-c206310a80f0> in <cell line: 1>()
# ----> 1 temp_mean = bikes.groupby(bikes['Date'].dt.week)['Temperature'].mean()
#       2 bikes_sum = bikes.groupby(bikes['Date'].dt.week)['Rental Count'].sum()
#
# AttributeError: 'DatetimeProperties' object has no attribute 'week'

# %%
bikes_week = pd.concat([temp_mean, bikes_sum], axis=1)

# %%
first_five = bikes_week.iloc[:5]
first_five
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-114-cb6f57df4463> in <cell line: 1>()
# ----> 1 first_five = bikes_week.iloc[:5]
#       2 first_five
#
# NameError: name 'bikes_week' is not defined

# %%
first_five['X - Mx'] = first_five[ 'Temperature'] - first_five[ 'Temperature'].mean ()
first_five['Y - My'] = first_five['Rental Count'] - first_five[ 'Rental Count'].mean ()
first_five
# Out:
# <ipython-input-125-f980a29d50a0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_five['X - Mx'] = first_five[ 'Temperature'] - first_five[ 'Temperature'].mean ()
# <ipython-input-125-f980a29d50a0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_five['Y - My'] = first_five['Rental Count'] - first_five[ 'Rental Count'].mean ()
#       Temperature  Rental Count    X - Mx  Y - My
# Date
# 1       -2.694940         39441  1.465357  6641.2
# ...

# %%
SSx = (first_five['X - Mx'] ** 2).sum()
SSy = (first_five['Y - My']**2).sum()
SP = first_five['X - Mx'] * first_five['Y - My'].sum()
print(SSx, SSy, SP)

r = SP / np. sqrt (SSx * SSy)
print(r)
# Out:
# 86.31974305555556 249778436.8 Date
# 1   -2.132375e-11
# 2    1.337997e-11
# 3   -9.928477e-11
# 4    8.554187e-11
# 5    2.168668e-11
# Name: X - Mx, dtype: float64
# Date
# 1   -1.452216e-16
# 2    9.112184e-17
# 3   -6.761610e-16
# 4    5.825675e-16
# 5    1.476932e-16
# Name: X - Mx, dtype: float64

# %%
first_five[ 'Temperature'].corr(first_five['Rental Count'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-113-7a2511049f1e> in <cell line: 1>()
# ----> 1 first_five[ 'Temperature'].corr(first_five['Rental Count'])
#
# NameError: name 'first_five' is not defined

# %%
bikes_week.plot('Temperature', 'Rental Count', kind='scatter')
# Out:
# <Axes: xlabel='Temperature', ylabel='Rental Count'>

# %%
bikes_week[ 'Temperature'].corr(bikes_week['Rental Count'])
# Out:
# 0.8458075200534891

# %%
bikes.corr()
# Out:
# <ipython-input-130-9a2604549c11>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   bikes.corr()
#                          Hour  Temperature  Humidity  Wind speed  Rainfall  \
# Hour             1.000000e+00     0.123610 -0.241644    0.285197  0.008715
# Temperature      1.236105e-01     1.000000  0.159793   -0.036418  0.050758
# Humidity        -2.416438e-01     0.159793  1.000000   -0.336683  0.236397
# Wind speed       2.851967e-01    -0.036418 -0.336683    1.000000 -0.019674
# Rainfall         8.714642e-03     0.050758  0.236397   -0.019674  1.000000
# Snowfall        -2.151645e-02    -0.217846  0.108183   -0.003554  0.008500
# Functioning Day  5.439377e-03    -0.049849 -0.020800    0.005037  0.002055
# Partner 1        3.145584e-01     0.408748 -0.149301    0.087161 -0.092278
# ...

# %%
humidity = bikes.groupby(bikes['Date'].dt.week)['Humidity'].mean()
wind_speed = bikes.groupby(bikes['Date'].dt.week)['Wind speed'].mean()
bikes_week = pd.concat([bikes_week, humidity, wind_speed], axis=1)
# Out:
# <ipython-input-131-729b132427d7>:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   humidity = bikes.groupby(bikes['Date'].dt.week)['Humidity'].mean()
# <ipython-input-131-729b132427d7>:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   wind_speed = bikes.groupby(bikes['Date'].dt.week)['Wind speed'].mean()

# %%
bikes_week.corr()
# Out:
#               Temperature  Rental Count  Humidity  Wind speed
# Temperature      1.000000      0.845808  0.584642   -0.420474
# Rental Count     0.845808      1.000000  0.389963   -0.434142
# Humidity         0.584642      0.389963  1.000000   -0.456225
# Wind speed      -0.420474     -0.434142 -0.456225    1.000000

# %%
bikes_week.plot('Humidity', 'Rental Count', kind='scatter')
# Out:
# <Axes: xlabel='Humidity', ylabel='Rental Count'>

# %%
bikes_week.plot('Wind speed', 'Rental Count', kind='scatter')
# Out:
# <Axes: xlabel='Wind speed', ylabel='Rental Count'>

# %%
bikes_week.corr()['Rental Count'].sort_values()
# Out:
# Wind speed     -0.434142
# Humidity        0.389963
# Temperature     0.845808
# Rental Count    1.000000
# Name: Rental Count, dtype: float64

# %%
bikes_week.corr()['Rental Count'].apply(np.abs).sort_values()
# Out:
# Humidity        0.389963
# Wind speed      0.434142
# Temperature     0.845808
# Rental Count    1.000000
# Name: Rental Count, dtype: float64

# %%
corr = bikes_week.corr ()
corr.abs().unstack()
# Out:
# Temperature   Temperature     1.000000
#               Rental Count    0.845808
#               Humidity        0.584642
#               Wind speed      0.420474
# Rental Count  Temperature     0.845808
#               Rental Count    1.000000
#               Humidity        0.389963
#               Wind speed      0.434142
# Humidity      Temperature     0.584642
#               Rental Count    0.389963
#               Humidity        1.000000
#               Wind speed      0.456225
# Wind speed    Temperature     0.420474
#               Rental Count    0.434142
#               Humidity        0.456225
#               Wind speed      1.000000
# dtype: float64

# %%
corr = bikes_week.corr()
corr.abs().unstack().sort_values()
# Out:
# Rental Count  Humidity        0.389963
# Humidity      Rental Count    0.389963
# Temperature   Wind speed      0.420474
# Wind speed    Temperature     0.420474
# Rental Count  Wind speed      0.434142
# Wind speed    Rental Count    0.434142
# Humidity      Wind speed      0.456225
# Wind speed    Humidity        0.456225
# Temperature   Humidity        0.584642
# Humidity      Temperature     0.584642
# Temperature   Rental Count    0.845808
# Rental Count  Temperature     0.845808
# Temperature   Temperature     1.000000
# Rental Count  Rental Count    1.000000
# Humidity      Humidity        1.000000
# Wind speed    Wind speed      1.000000
# dtype: float64

# %% [markdown]
# # Тема 8 Ввведение в визуализацию данных

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
bikes = pd.read_pickle('gdrive/MyDrive/Data_analysis/Общие материалы/Лекции/BikesDataImputed.pkl')
bikes .head()
# Out:
#         Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 0 2017-12-01     0         -5.2        37         2.2       0.0       0.0
# 1 2017-12-01     1         -5.5        38         0.8       0.0       0.0
# 2 2017-12-01     2         -6.0        39         1.0       0.0       0.0
# 3 2017-12-01     3         -6.2        40         0.9       0.0       0.0
# 4 2017-12-01     4         -6.0        36         2.3       0.0       0.0
#
#   Seasons  Holiday  Functioning Day  Rental Count  Normal Humidity  \
# 0  Winter        0             True           257                0
# 1  Winter        0             True           219                0
# 2  Winter        0             True           162                0
# 3  Winter        0             True           148                1
# 4  Winter        0             True            97                0
#
#   Temperature Category  Good Weather
# 0             Freezing             0
# 1             Freezing             0
# ...

# %%
month_weather = bikes.groupby(bikes[ 'Date'].dt.month)['Temperature'].mean ()
month_weather
# Out:
# Date
# 1     -3.957460
# 2     -1.677009
# 3      8.049597
# 4     12.970278
# 5     18.129368
# 6     23.134375
# 7     27.766062
# 8     28.719556
# 9     21.490208
# 10    13.095161
# 11     7.785069
# 12    -1.932594
# Name: Temperature, dtype: float64

# %%
plt.bar(month_weather.index, month_weather, color='orange')
# Out:
# <BarContainer object of 12 artists>

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(month_weather.index, month_weather, color='orange')
# Out:
# <BarContainer object of 12 artists>

# %%
bikes_sum = bikes.groupby(bikes['Date'].dt.week)['Rental Count'].sum()
bikes_sum
# Out:
# <ipython-input-148-8309b5410f7a>:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   bikes_sum = bikes.groupby(bikes['Date'].dt.week)['Rental Count'].sum()
# Date
# 1      39441
# 2      30871
# 3      42193
# 4      23079
# 5      28415
# 6      33259
# 7      32139
# 8      50136
# 9      52958
# 10     77316
# 11     90547
# 12     79109
# 13    118031
# 14     97000
# 15     98468
# 16    142918
# 17    141147
# 18    146127
# 19    136607
# 20    142346
# 21    189749
# 22    210326
# 23    211869
# 24    220392
# 25    213553
# 26    146455
# 27    183652
# 28    154848
# 29    172636
# 30    163447
# 31    135086
# 32    147911
# 33    166679
# 34    152282
# 35    138529
# 36    191800
# 37    186208
# 38    103925
# 39    124820
# 40     99622
# 41    159527
# 42    185695
# 43    141509
# 44    123557
# 45     66682
# 46    142787
# 47    103454
# 48    107727
# 49     48680
# 50     40147
# ...

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.plot(bikes_sum)

# %%
seasons = bikes.groupby(['Seasons', 'Date']) ['Rental Count']. sum()
seasons.loc['Autumn']
# Out:
# Date
# 2018-09-01    25495
# 2018-09-02    33943
# 2018-09-03    10753
# 2018-09-04    31363
# 2018-09-05    34816
#               ...
# 2018-11-26    13934
# 2018-11-27    13964
# 2018-11-28    17378
# 2018-11-29    18058
# 2018-11-30    17543
# Name: Rental Count, Length: 91, dtype: int64

# %%
fig, ax = plt. subplots (figsize= (10,5))
ax.plot(seasons. loc['Autumn'])
ax.plot(seasons.loc['Winter'])
ax.plot(seasons.loc[ 'Spring'])
ax.plot(seasons. loc[ 'Summer'])
ax. legend (['Autumn', 'Winter', 'Spring', 'Summer'], frameon=False)

# %%
daily_temp = bikes.groupby([ 'Seasons', 'Date']) ['Temperature']. mean ()
daily_temp
# Out:
# Seasons  Date
# Autumn   2018-09-01    25.402083
#          2018-09-02    24.987500
#          2018-09-03    23.604167
#          2018-09-04    23.254167
#          2018-09-05    23.783333
#                          ...
# Winter   2018-02-24     2.762500
#          2018-02-25     1.916667
#          2018-02-26     2.725000
#          2018-02-27     3.958333
#          2018-02-28     4.850000
# Name: Temperature, Length: 365, dtype: float64

# %%
fig, ax = plt.subplots(2,2, figsize=(20,10))

ax[0][0].plot(daily_temp.loc['Winter'], c='blue')
ax[0][1].plot(daily_temp.loc['Spring'], c='green')
ax[1][0].plot(daily_temp.loc[ 'Summer'], c='#ff8c69')
ax[1][1].plot(daily_temp.loc['Autumn'], c='red')

# %%
fig, ax = plt.subplots(2,2, figsize=(20,10))

ax[0][0].plot(daily_temp.loc['Winter'], c='blue')
ax[0][1].plot(daily_temp.loc['Spring'], c='green')
ax[1][0].plot(daily_temp.loc[ 'Summer'], c='#ff8c69')
ax[1][1].plot(daily_temp.loc['Autumn'], c='red')

for axis in ax.ravel():
  #axis.set_ylim(-20,35)
  axis.set_xlabel( 'Date')
  axis.set_ylabel( 'Temperature')
  axis.axhline(12.9, c='black', lw=1, ls=':')
  axis.spines['right'].set_visible(False)
  axis.spines['top'].set_visible(False)
ax[0][0].legend(['Winter', 'Annual average'], frameon=False)
ax[0][1].legend([ 'Spring''Annual average'], frameon=False)
ax[1][0]. legend (['Summer', 'Annual average'], frameon=False)
ax[1][1].legend(['Autumn', 'Annual average'], frameon=False)
fig.suptitle( 'Temperature daily means by season', fontsize=20)
# Out:
# Text(0.5, 0.98, 'Temperature daily means by season')

# %%
fig.savefig('temps.pdf')
fig.savefig('temps.png', dpi=100)

# %%
bikes['No work day'] = np.where(bikes['Date'].dt.day_name().isin(['Saturday', 'Sunday']) + bikes['Holiday'], 1, 0)

# %%
bikes['Rainfall and Snowfall'] = bikes['Rainfall'] * 10 + bikes['Snowfall']

# %%
bikes_sum = bikes.groupby('Date')['Rental Count'].sum()
temp_av = bikes.groupby('Date')['Temperature'].mean()
rainsnow_av = bikes.groupby('Date')['Rainfall and Snowfall'].mean()
no_work = bikes.groupby('Date')['No work day'].max()
bikes_date = pd.concat([bikes_sum, temp_av, rainsnow_av, no_work], axis=1)

# %%
fig, ax = plt.subplots(figsize=(10,7))
graph = ax.scatter(bikes_date[ 'Temperature'], bikes_date[ 'Rental Count'])

# %%
fig, ax = plt.subplots(figsize=(10,7))
graph = ax.scatter(bikes_date[ 'Temperature'], bikes_date[ 'Rental Count'],
           c=bikes_date[ 'No work day'], s=bikes_date[ 'Rainfall and Snowfall']*10,
           alpha = 0.7)

plt.colorbar(graph, label = 'Не рабочие дни')
ax.set_title('Зависимость числа арендованных велосипедов в сутки от температу ры, выходного дня и количества осадков')
# Out:
# Text(0.5, 1.0, 'Зависимость числа арендованных велосипедов в сутки от температу ры, выходного дня и количества осадков')

# %% [markdown]
# ## Разведочный анализ данных![изображение_2024-03-23_051703013.png](data:image/png;base64,...![изображение_2024-03-23_054131655.png](data:image/png;base64,...![изображение_2024-03-23_054144124.png](data:image/png;base64,...)))

# %%
import seaborn as sns

# %%
df = pd.read_csv("gdrive/MyDrive/Data_analysis/Общие материалы/Лекции/heart.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  target
# 0   63    1   3       145   233    1        0      150      0       1
# 1   37    1   2       130   250    0        1      187      0       1
# 2   41    0   1       130   204    0        0      172      0       1
# 3   56    1   1       120   236    0        1      178      0       1
# 4   57    0   0       120   354    0        1      163      1       1

# %% [markdown]
# • age — возраст пациента
#
# • sex — пол пациента (1 = мужчина, 0 = женщина)
#
# • ср — тип боли в груди (1 = типичная стенокардия, 2 = атипичная стенокардия, 3 = другой вид боли, 4 = нет боли)
#
# • trestbps — артериальное давление в состоянии покоя (мм ртутного столба, на момент госпитализации)
#
# • chol — уровень холестерола (мг/дл)
#
# • fbs — уровень сахара в крови натощак выше 120 мг/дл (1 = да, 0 = нет)
#
# • restecg - результат ЭКГ в состоянии покоя (0 = нормальный, 1 = абнормальный, 2 = признаки гипертрофии желудочка)
#
# • thalach — максимальная зафиксированная частота сердцебиения
#
# • exang — стенокардия в результате физической нагрузки (1 = да, 0 = нет)
#
# • target — наличие сердечно-сосудистого заболевания (1 = да, 0 = нет)

# %%
num_features = ['age', 'trestbps', 'chol', 'thalach']
cat_features = ['sex', 'cp', 'fbs', 'restecg', 'exang', 'target']

# %%
sns.distplot(df['age'])
# Out:
# <ipython-input-184-7452d86f8334>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'])
# <Axes: xlabel='age', ylabel='Density'>

# %%
df['target'].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
sns.barplot(x=df['target'].value_counts().index, y=df['target'].value_counts ())
# Out:
# <Axes: xlabel='None', ylabel='target'>

# %%
sns.violinplot(x=df['target'], y=df['age'])
# Out:
# <Axes: xlabel='target', ylabel='age'>

# %%
sns.boxplot(x=df['target'], y=df['age'])
# Out:
# <Axes: xlabel='target', ylabel='age'>

# %%
correlation = df.corr().loc[num_features, num_features]
correlation
# Out:
#                age  trestbps      chol   thalach
# age       1.000000  0.279351  0.213678 -0.398522
# trestbps  0.279351  1.000000  0.123174 -0.046698
# chol      0.213678  0.123174  1.000000 -0.009940
# thalach  -0.398522 -0.046698 -0.009940  1.000000

# %%
fig, ax = plt.subplots(figsize = (14,12))
sns.heatmap(correlation, annot=True, linecolor='white', linewidth=0.5,
            annot_kws = {'size' :20}, vmax = 1, vmin=-1)
# Out:
# <Axes: >

# %%
sns.pairplot(df[num_features])

# %% [markdown]
# # Тема 9 Линейная ригрессия

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Коэфициент детерминации
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import seaborn as sns
import matplotlib. pyplot as plt
import scipy.stats
import statsmodels.api as sm
import numpy as np

bikes = pd.read_pickle('gdrive/MyDrive/Data_analysis/Общие материалы/Лекции/BikesDataImputed.pkl')
bikes.head()
# Out:
#         Date  Hour  Temperature  Humidity  Wind speed  Rainfall  Snowfall  \
# 0 2017-12-01     0         -5.2        37         2.2       0.0       0.0
# 1 2017-12-01     1         -5.5        38         0.8       0.0       0.0
# 2 2017-12-01     2         -6.0        39         1.0       0.0       0.0
# 3 2017-12-01     3         -6.2        40         0.9       0.0       0.0
# 4 2017-12-01     4         -6.0        36         2.3       0.0       0.0
#
#   Seasons  Holiday  Functioning Day  Rental Count  Normal Humidity  \
# 0  Winter        0             True           257                0
# 1  Winter        0             True           219                0
# 2  Winter        0             True           162                0
# 3  Winter        0             True           148                1
# 4  Winter        0             True            97                0
#
#   Temperature Category  Good Weather
# 0             Freezing             0
# 1             Freezing             0
# ...

# %%
bikes_sum = bikes.groupby(bikes['Date'].dt.week)['Rental Count'].sum()
temp_mean = bikes.groupby(bikes['Date'].dt.week)['Temperature'].mean ()
humidity_mean = bikes.groupby(bikes['Date'].dt.week) ['Humidity'].mean()
wind_mean = bikes.groupby(bikes['Date'].dt.week)['Wind speed'].mean()
bikes_weeks = pd.concat([bikes_sum, temp_mean, humidity_mean, wind_mean], axis=1)

bikes_weeks.head()
# Out:
# <ipython-input-207-1f493137a7ac>:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   bikes_sum = bikes.groupby(bikes['Date'].dt.week)['Rental Count'].sum()
# <ipython-input-207-1f493137a7ac>:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   temp_mean = bikes.groupby(bikes['Date'].dt.week)['Temperature'].mean ()
# <ipython-input-207-1f493137a7ac>:3: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   humidity_mean = bikes.groupby(bikes['Date'].dt.week) ['Humidity'].mean()
# <ipython-input-207-1f493137a7ac>:4: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   wind_mean = bikes.groupby(bikes['Date'].dt.week)['Wind speed'].mean()
# ...

# %%
plt.figure(figsize=(20,20))

p = sns.heatmap(bikes_weeks.corr(), annot = True, vmin = -1,vmax = 1)

# %%
sns.pairplot(bikes_weeks)

# %%
X = bikes_weeks['Temperature']
y = bikes_weeks['Rental Count']
res = scipy.stats.linregress (X, y)
print(res)
# Out:
# LinregressResult(slope=4309.320603391841, intercept=61741.699243285024, rvalue=0.8458075200534889, pvalue=2.992184317240584e-15, stderr=384.39441030665824, intercept_stderr=6596.057490467339)

# %%
r_sq = res.rvalue ** 2
print(r_sq)
# Out:
# 0.7153903609790331

# %%
plt.scatter(X, y, label = 'оригинальные данные')
plt.plot(X, res.intercept + res.slope * X, 'r', label = 'линия регрессии')
plt.legend()
plt.show()

# %%
X_simple = bikes_weeks[ 'Temperature']
y = bikes_weeks['Rental Count']
X_simple_constant = sm.add_constant(X_simple)
model = sm.OLS (y, X_simple_constant)
res_simple = model.fit()
print(res_simple.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Rental Count   R-squared:                       0.715
# Model:                            OLS   Adj. R-squared:                  0.710
# Method:                 Least Squares   F-statistic:                     125.7
# Date:                Sat, 23 Mar 2024   Prob (F-statistic):           2.99e-15
# Time:                        02:46:54   Log-Likelihood:                -611.13
# No. Observations:                  52   AIC:                             1226.
# Df Residuals:                      50   BIC:                             1230.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        6.174e+04   6596.057      9.360      0.000    4.85e+04     7.5e+04
# ...

# %%
X_mult = sm.add_constant(bikes_weeks.drop('Rental Count', axis=1))
model = sm.OLS (y, X_mult)
res_mult = model. fit()
print (res_mult.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Rental Count   R-squared:                       0.749
# Model:                            OLS   Adj. R-squared:                  0.733
# Method:                 Least Squares   F-statistic:                     47.63
# Date:                Sat, 23 Mar 2024   Prob (F-statistic):           1.99e-14
# Time:                        02:49:12   Log-Likelihood:                -607.91
# No. Observations:                  52   AIC:                             1224.
# Df Residuals:                      48   BIC:                             1232.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        1.756e+05   4.61e+04      3.807      0.000    8.29e+04    2.68e+05
# ...
